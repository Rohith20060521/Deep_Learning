# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohith20060521/Deep_Learning/blob/main/IrisData_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow import argmax
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
#Load iris data
iris=load_iris()
x=iris.data
y=iris.target
target_names=iris.target_names
print(target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
# Split dataset
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#standardize features
scalar=StandardScaler()
x_train=scalar.fit_transform(x_train)
x_test=scalar.transform(x_test)

# %%
#define model
model=Sequential()
model.add(Dense(10,activation='relu',input_shape=(x_train.shape[1],)))
model.add(Dense(10,activation='relu'))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193 (772.00 B)
#  Trainable params: 193 (772.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,validation_split=0.1,epochs=50,verbose=1,batch_size=8)
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.5725 - loss: 0.9137 - val_accuracy: 0.5833 - val_loss: 0.8776
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7367 - loss: 0.8481 - val_accuracy: 0.5833 - val_loss: 0.8407
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7205 - loss: 0.7870 - val_accuracy: 0.5833 - val_loss: 0.8046
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7656 - loss: 0.7280 - val_accuracy: 0.5833 - val_loss: 0.7699
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6052 - loss: 0.7523 - val_accuracy: 0.5833 - val_loss: 0.7381
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6801 - loss: 0.6524 - val_accuracy: 0.6667 - val_loss: 0.7087
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6889 - loss: 0.6296 - val_accuracy: 0.6667 - val_loss: 0.6804
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7140 - loss: 0.5651 - val_accuracy: 0.6667 - val_loss: 0.6553
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7539 - loss: 0.4837 - val_accuracy: 0.7500 - val_loss: 0.6334
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7819 - loss: 0.5091 - val_accuracy: 0.7500 - val_loss: 0.6128
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7644 - loss: 0.5415 - val_accuracy: 0.7500 - val_loss: 0.5940
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7791 - loss: 0.5185 - val_accuracy: 0.7500 - val_loss: 0.5773
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8163 - loss: 0.4715 - val_accuracy: 0.8333 - val_loss: 0.5612
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8063 - loss: 0.4805 - val_accuracy: 0.8333 - val_loss: 0.5472
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8060 - loss: 0.4581 - val_accuracy: 0.8333 - val_loss: 0.5339
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7827 - loss: 0.4396 - val_accuracy: 0.7500 - val_loss: 0.5213
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8463 - loss: 0.3606 - val_accuracy: 0.7500 - val_loss: 0.5096
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8435 - loss: 0.4153 - val_accuracy: 0.7500 - val_loss: 0.4981
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8088 - loss: 0.4026 - val_accuracy: 0.8333 - val_loss: 0.4855
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8360 - loss: 0.3798 - val_accuracy: 0.8333 - val_loss: 0.4689
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8608 - loss: 0.3519 - val_accuracy: 0.9167 - val_loss: 0.4464
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8425 - loss: 0.3337 - val_accuracy: 0.9167 - val_loss: 0.4221
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8130 - loss: 0.3766 - val_accuracy: 0.9167 - val_loss: 0.4011
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9270 - loss: 0.3109 - val_accuracy: 0.9167 - val_loss: 0.3879
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9008 - loss: 0.2973 - val_accuracy: 0.9167 - val_loss: 0.3789
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8981 - loss: 0.3188 - val_accuracy: 0.9167 - val_loss: 0.3664
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9184 - loss: 0.2917 - val_accuracy: 0.9167 - val_loss: 0.3574
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8977 - loss: 0.2930 - val_accuracy: 0.9167 - val_loss: 0.3493
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9306 - loss: 0.2830 - val_accuracy: 0.9167 - val_loss: 0.3417
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9513 - loss: 0.2179 - val_accuracy: 0.9167 - val_loss: 0.3296
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8999 - loss: 0.2809 - val_accuracy: 0.9167 - val_loss: 0.3255
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9270 - loss: 0.2587 - val_accuracy: 0.9167 - val_loss: 0.3189
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9647 - loss: 0.2498 - val_accuracy: 0.9167 - val_loss: 0.3060
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9418 - loss: 0.2270 - val_accuracy: 0.9167 - val_loss: 0.3000
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9625 - loss: 0.2004 - val_accuracy: 0.9167 - val_loss: 0.2941
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9629 - loss: 0.1935 - val_accuracy: 0.9167 - val_loss: 0.2852
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9510 - loss: 0.2059 - val_accuracy: 0.9167 - val_loss: 0.2774
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9580 - loss: 0.1879 - val_accuracy: 0.9167 - val_loss: 0.2682
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9491 - loss: 0.2034 - val_accuracy: 0.9167 - val_loss: 0.2646
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9388 - loss: 0.2016 - val_accuracy: 0.9167 - val_loss: 0.2590
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9731 - loss: 0.1763 - val_accuracy: 0.9167 - val_loss: 0.2519
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9262 - loss: 0.1813 - val_accuracy: 0.9167 - val_loss: 0.2413
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9640 - loss: 0.1357 - val_accuracy: 0.9167 - val_loss: 0.2457
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9423 - loss: 0.1681 - val_accuracy: 0.9167 - val_loss: 0.2320
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9279 - loss: 0.1754 - val_accuracy: 0.9167 - val_loss: 0.2246
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9209 - loss: 0.1762 - val_accuracy: 0.9167 - val_loss: 0.2262
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9635 - loss: 0.1368 - val_accuracy: 0.9167 - val_loss: 0.2183
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9337 - loss: 0.1473 - val_accuracy: 0.9167 - val_loss: 0.2137
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9655 - loss: 0.1235 - val_accuracy: 0.9167 - val_loss: 0.2073
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9610 - loss: 0.1360 - val_accuracy: 0.9167 - val_loss: 0.2048

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f" Test Accuracy: ", test_acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 1.0000 - loss: 0.1189
#  Test Accuracy:  1.0

# %%
# Make Prediction
y_pred_prob=model.predict(x_test)
y_pred=argmax(y_pred_prob,axis=1)
#Calculate Accuracy
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# Accuracy: 1.0

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
df=pd.read_csv("/content/drive/MyDrive/CarPrice_dataset.csv")
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df=df.drop_duplicates()

# %%
df=pd.get_dummies(df,drop_first=True)
print(df.head())
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  ...  cylindernumber_three  \
# 0         130       3.47    2.68  ...                 False
# 1         130       3.47    2.68  ...                 False
# 2         152       2.68    3.47  ...                 False
# 3         109       3.19    3.40  ...                 False
# 4         136       3.19    3.40  ...                 False
#
#    cylindernumber_twelve  cylindernumber_two  fuelsystem_2bbl  \
# 0                  False               False            False
# 1                  False               False            False
# 2                  False               False            False
# 3                  False               False            False
# 4                  False               False            False
#
#    fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mfi  fuelsystem_mpfi  \
# 0            False           False           False             True
# 1            False           False           False             True
# 2            False           False           False             True
# 3            False           False           False             True
# 4            False           False           False             True
#
#    fuelsystem_spdi  fuelsystem_spfi
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
#
# [5 rows x 191 columns]

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
scaler=StandardScaler()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)
model=Sequential()
model.add(Dense(512,activation='relu',input_shape=(x_train.shape[1],)))
model.add(Dense(256,activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(1))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                │ (None, 512)            │        97,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 272,385 (1.04 MB)
#  Trainable params: 272,385 (1.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['mae'])

# %%
history=model.fit(x_train,y_train,validation_split=0.2,epochs=70,batch_size=32)
# Out:
# Epoch 1/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 517ms/step - loss: 202720000.0000 - mae: 12447.1289 - val_loss: 266323344.0000 - val_mae: 13293.1719
# Epoch 2/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 154256336.0000 - mae: 10104.0312 - val_loss: 178727136.0000 - val_mae: 9502.0098
# Epoch 3/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 88610768.0000 - mae: 6505.6338 - val_loss: 88286600.0000 - val_mae: 6555.5884
# Epoch 4/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 58464968.0000 - mae: 6163.7217 - val_loss: 91985536.0000 - val_mae: 8047.5342
# Epoch 5/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 61850524.0000 - mae: 6688.2881 - val_loss: 88785944.0000 - val_mae: 6356.0801
# Epoch 6/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 46232620.0000 - mae: 4906.2114 - val_loss: 108207480.0000 - val_mae: 6578.5352
# Epoch 7/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 53345056.0000 - mae: 4789.0708 - val_loss: 101315888.0000 - val_mae: 6407.9800
# Epoch 8/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 40324072.0000 - mae: 4302.1323 - val_loss: 84973264.0000 - val_mae: 6133.9858
# Epoch 9/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 41475880.0000 - mae: 4762.2534 - val_loss: 78249056.0000 - val_mae: 6212.5420
# Epoch 10/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 51012400.0000 - mae: 5298.5811 - val_loss: 78441272.0000 - val_mae: 6062.7988
# Epoch 11/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 43963404.0000 - mae: 4827.0005 - val_loss: 79560064.0000 - val_mae: 5936.2021
# Epoch 12/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 38134676.0000 - mae: 4561.2778 - val_loss: 70604888.0000 - val_mae: 6199.6831
# Epoch 13/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 41423400.0000 - mae: 5194.4814 - val_loss: 68201768.0000 - val_mae: 6341.5234
# Epoch 14/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 42686432.0000 - mae: 5333.9092 - val_loss: 66651460.0000 - val_mae: 5880.5840
# Epoch 15/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 38446076.0000 - mae: 4736.7319 - val_loss: 71910424.0000 - val_mae: 5537.6821
# Epoch 16/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 36751992.0000 - mae: 4247.7886 - val_loss: 71107512.0000 - val_mae: 5425.7397
# Epoch 17/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 34180580.0000 - mae: 4053.6519 - val_loss: 63277240.0000 - val_mae: 5418.7085
# Epoch 18/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 34390120.0000 - mae: 4400.2075 - val_loss: 56536860.0000 - val_mae: 5522.5889
# Epoch 19/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 33548940.0000 - mae: 4442.9678 - val_loss: 56523936.0000 - val_mae: 5163.8809
# Epoch 20/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 32802170.0000 - mae: 4221.7798 - val_loss: 52608496.0000 - val_mae: 4973.3677
# Epoch 21/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 27148808.0000 - mae: 3789.2197 - val_loss: 53597020.0000 - val_mae: 4725.3062
# Epoch 22/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 25957344.0000 - mae: 3550.7126 - val_loss: 44470696.0000 - val_mae: 4706.9878
# Epoch 23/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29441902.0000 - mae: 3981.6433 - val_loss: 40478276.0000 - val_mae: 4669.2310
# Epoch 24/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 26164800.0000 - mae: 4014.4243 - val_loss: 38656824.0000 - val_mae: 4323.1836
# Epoch 25/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 24208744.0000 - mae: 3364.9128 - val_loss: 37158580.0000 - val_mae: 4008.2883
# Epoch 26/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18035998.0000 - mae: 3191.1221 - val_loss: 30220744.0000 - val_mae: 4150.6763
# Epoch 27/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18060276.0000 - mae: 3091.5642 - val_loss: 34864912.0000 - val_mae: 3527.5527
# Epoch 28/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19618566.0000 - mae: 2671.4485 - val_loss: 27752222.0000 - val_mae: 3474.7051
# Epoch 29/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24431772.0000 - mae: 3283.8879 - val_loss: 25741314.0000 - val_mae: 3503.2295
# Epoch 30/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18617804.0000 - mae: 2897.9668 - val_loss: 27386938.0000 - val_mae: 3295.3528
# Epoch 31/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24288214.0000 - mae: 3025.6689 - val_loss: 24001952.0000 - val_mae: 3491.6528
# Epoch 32/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19097738.0000 - mae: 2845.0972 - val_loss: 26759780.0000 - val_mae: 3248.6372
# Epoch 33/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 23571926.0000 - mae: 3007.6042 - val_loss: 24767834.0000 - val_mae: 3225.1211
# Epoch 34/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 16234126.0000 - mae: 2603.6448 - val_loss: 22549480.0000 - val_mae: 3385.9124
# Epoch 35/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 22141492.0000 - mae: 3238.1411 - val_loss: 21818440.0000 - val_mae: 3250.2092
# Epoch 36/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19684222.0000 - mae: 2851.4902 - val_loss: 24074944.0000 - val_mae: 3142.0393
# Epoch 37/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20207934.0000 - mae: 2716.9453 - val_loss: 21105238.0000 - val_mae: 3316.3293
# Epoch 38/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18564696.0000 - mae: 2948.6392 - val_loss: 23052238.0000 - val_mae: 3127.2339
# Epoch 39/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20630720.0000 - mae: 2819.8489 - val_loss: 22085078.0000 - val_mae: 3208.9688
# Epoch 40/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19318260.0000 - mae: 2788.4568 - val_loss: 22625134.0000 - val_mae: 3152.6458
# Epoch 41/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 14641064.0000 - mae: 2443.2305 - val_loss: 21037030.0000 - val_mae: 3313.6399
# Epoch 42/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30485474.0000 - mae: 4091.1719 - val_loss: 21591670.0000 - val_mae: 3333.5935
# Epoch 43/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19977936.0000 - mae: 2801.7502 - val_loss: 35981236.0000 - val_mae: 3718.7585
# Epoch 44/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18986498.0000 - mae: 2735.4727 - val_loss: 23726010.0000 - val_mae: 3886.5039
# Epoch 45/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 24065664.0000 - mae: 4019.4878 - val_loss: 22974498.0000 - val_mae: 3700.6167
# Epoch 46/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20902732.0000 - mae: 3235.8123 - val_loss: 27085532.0000 - val_mae: 3236.4358
# Epoch 47/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21340746.0000 - mae: 2628.2192 - val_loss: 23399054.0000 - val_mae: 3281.5925
# Epoch 48/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 16296397.0000 - mae: 2848.4209 - val_loss: 21176442.0000 - val_mae: 3482.3328
# Epoch 49/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19773980.0000 - mae: 3016.7654 - val_loss: 26862630.0000 - val_mae: 3198.8674
# Epoch 50/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 16225655.0000 - mae: 2325.4709 - val_loss: 23064886.0000 - val_mae: 3076.7566
# Epoch 51/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 16908620.0000 - mae: 2616.4202 - val_loss: 20214296.0000 - val_mae: 3166.0642
# Epoch 52/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15221914.0000 - mae: 2627.3210 - val_loss: 22496474.0000 - val_mae: 3055.4592
# Epoch 53/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15141447.0000 - mae: 2364.1826 - val_loss: 20245116.0000 - val_mae: 3116.8850
# Epoch 54/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21507656.0000 - mae: 2996.5762 - val_loss: 19670974.0000 - val_mae: 3157.7751
# Epoch 55/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 20537988.0000 - mae: 2862.7891 - val_loss: 25407222.0000 - val_mae: 3144.9590
# Epoch 56/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19566356.0000 - mae: 2575.3855 - val_loss: 22423672.0000 - val_mae: 3058.5205
# Epoch 57/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15139885.0000 - mae: 2477.1982 - val_loss: 21174188.0000 - val_mae: 3658.9731
# Epoch 58/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20627534.0000 - mae: 3652.0229 - val_loss: 20310490.0000 - val_mae: 3088.3950
# Epoch 59/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 19503144.0000 - mae: 2823.3240 - val_loss: 33321312.0000 - val_mae: 3692.3027
# Epoch 60/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18743450.0000 - mae: 2726.9722 - val_loss: 20352158.0000 - val_mae: 3442.5259
# Epoch 61/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 20492468.0000 - mae: 3414.7747 - val_loss: 20941932.0000 - val_mae: 3187.6870
# Epoch 62/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 19969302.0000 - mae: 2701.2324 - val_loss: 27421590.0000 - val_mae: 3201.6289
# Epoch 63/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 18666440.0000 - mae: 2427.5837 - val_loss: 21542920.0000 - val_mae: 3124.9353
# Epoch 64/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 18982344.0000 - mae: 2761.3677 - val_loss: 19778330.0000 - val_mae: 3258.2261
# Epoch 65/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 16363792.0000 - mae: 2751.1736 - val_loss: 20992466.0000 - val_mae: 3028.2190
# Epoch 66/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 16619653.0000 - mae: 2384.1638 - val_loss: 19748632.0000 - val_mae: 2997.9924
# Epoch 67/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 17638706.0000 - mae: 2647.8394 - val_loss: 18545364.0000 - val_mae: 3120.8447
# Epoch 68/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 24165140.0000 - mae: 3293.1555 - val_loss: 20860626.0000 - val_mae: 3003.8130
# Epoch 69/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20021490.0000 - mae: 2562.5957 - val_loss: 23573634.0000 - val_mae: 3083.1145
# Epoch 70/70
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18647342.0000 - mae: 2457.2354 - val_loss: 18632460.0000 - val_mae: 3197.5481

# %%
test_loss,mae=model.evaluate(x_test_scaled,y_test)
print(f" Test mae: ", mae)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - loss: 261090592.0000 - mae: 13441.2148
#  Test mae:  13407.8671875

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error,r2_score
y_pred=model.predict(x_test_scaled)
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=root_mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R-squared: {r2}")
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b8c2030af20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step
# Mean Squared Error: 257122211.3417872
# Mean Absolute Error: 13407.86755206719
# Root Mean Squared Error: 16035.030755872818
# R-squared: -2.2570194484233896

# %%
#Ploting data
import matplotlib.pyplot as plt
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
new_car = {
    'enginesize': 1800,
    'citympg': 15
}
new_car_df = pd.DataFrame([new_car])
new_car_df = new_car_df.reindex(columns=x_train.columns, fill_value=0)
new_car_scaled = scaler.transform(new_car_df)
predicted_price = model.predict(new_car_scaled)
price = predicted_price[0][0] * 1000
print(f"Predicted Price = ₹{price:,.0f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# Predicted Price = ₹774,900
